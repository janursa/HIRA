# %%
import cellflow
import pertpy
# cellflow.datasets.ineurons(path='ineurons.h5ad', force_download=False)
# adata = pertpy.data.combosciplex()
adata = cellflow.datasets.zesta()
# Out:
# 100%|██████████| 5.81G/5.81G [04:23<00:00, 23.7MB/s]

# %%
# adata.obs

# %%
df = adata.obs.groupby(['gene_target_1', 'gene_target_2']).size().sort_values(ascending=False)
df[df>0].shape
# Out:
# /vol/tmp/users/jnourisa/ipykernel_1343740/508546818.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = adata.obs.groupby(['gene_target_1', 'gene_target_2']).size().sort_values(ascending=False)
# (24,)

# %%
import anndata as ad 
ad.read_h5ad('../nakatake_.portia.portia.prediction.h5ad').uns['prediction']
# Out:
#         source     target                weight
# 0       ZNF716  LINC02043                   1.0
# 1       ZNF679  LINC02043    0.9999999998228658
# 2       MYCLP1  LINC02043    0.9999999997510962
# 3      ZSCAN5C  LINC02043    0.9999999995984333
# 4      TGIF2LX  LINC02043    0.9999999993675268
# ...        ...        ...                   ...
# 49995   DMRTC2     PLXNB3  0.010339125727320132
# 49996   DMRTC2   OR7E109P   0.01033863497672699
# 49997   ZNF479   SLC25A45  0.010338540632343941
# 49998     AIRE      ICAM5  0.010338465016289565
# 49999   ZNF716    CCDC175   0.01033835515399038
#
# [50000 rows x 3 columns]
