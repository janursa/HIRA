# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys 
import scanpy as sc
import warnings
import scanpy as sc
import anndata as ad
import os
from scipy.sparse import issparse
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)
plt.rcParams["font.family"] = "Arial"

# %%
from helper import get_intervention_signature
get_intervention_signature(intervention='Ruxolitinib', cell_type='CD4T')
# Out:
# 'INTERVENTION SIGNATURE FOR RUXOLITINIB in CD4T (tfa_major_b)\nTotal significant features: 187\n\nDECREASED BY INTERVENTION:\n  ↓ AHR: slope=-0.5202, p_adj=0.0101\n  ↓ ARHGAP35: slope=-0.4750, p_adj=0.0028\n  ↓ ARID3B: slope=-0.1707, p_adj=0.0499\n  ↓ ATF3: slope=-0.4511, p_adj=0.0089\n  ↓ ATF7: slope=-0.1857, p_adj=0.0497\n  ↓ BATF: slope=-1.5083, p_adj=0.0000\n  ↓ BHLHE40: slope=-1.1400, p_adj=0.0000\n  ↓ CAMTA1: slope=-0.4479, p_adj=0.0006\n  ↓ CC2D1A: slope=-0.2040, p_adj=0.0066\n  ↓ CDC5L: slope=-0.3634, p_adj=0.0007\n  ↓ CEBPG: slope=-0.4422, p_adj=0.0000\n  ↓ CENPS: slope=-0.4348, p_adj=0.0111\n  ↓ CENPX: slope=-0.7897, p_adj=0.0001\n  ↓ CHCHD3: slope=-0.6570, p_adj=0.0000\n  ↓ CLOCK: slope=-0.3627, p_adj=0.0185\n  ↓ CREB3L2: slope=-0.4262, p_adj=0.0005\n  ↓ DNTTIP1: slope=-0.6028, p_adj=0.0000\n  ↓ DR1: slope=-0.5957, p_adj=0.0036\n  ↓ DRAP1: slope=-0.8597, p_adj=0.0479\n  ↓ E2F2: slope=-0.4643, p_adj=0.0014\n\nINCREASED BY INTERVENTION:\n  ↑ ADNP: slope=0.1770, p_adj=0.0059\n  ↑ AEBP1: slope=0.1828, p_adj=0.0085\n  ↑ ANKZF1: slope=0.1718, p_adj=0.0042\n  ↑ ASH1L: slope=0.8376, p_adj=0.0218\n  ↑ BACH2: slope=1.6600, p_adj=0.0000\n  ↑ BCL11B: slope=1.2162, p_adj=0.0005\n  ↑ CGGBP1: slope=0.3784, p_adj=0.0158\n  ↑ CREBZF: slope=0.2804, p_adj=0.0059\n  ↑ EEA1: slope=0.6712, p_adj=0.0003\n  ↑ ELK4: slope=0.1102, p_adj=0.0168\n  ↑ ETS1: slope=1.4929, p_adj=0.0046\n  ↑ FOXN3: slope=1.0235, p_adj=0.0040\n  ↑ FOXO1: slope=0.7882, p_adj=0.0001\n  ↑ FOXP1: slope=1.8460, p_adj=0.0000\n  ↑ HIF1A: slope=0.6644, p_adj=0.0017\n  ↑ HIVEP1: slope=0.6100, p_adj=0.0006\n  ↑ HIVEP2: slope=0.5697, p_adj=0.0333\n  ↑ IKZF1: slope=1.1984, p_adj=0.0041\n  ↑ IKZF5: slope=0.2371, p_adj=0.0329\n  ↑ KLF12: slope=0.5864, p_adj=0.0367\n'
